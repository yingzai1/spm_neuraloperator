# %%
import numpy as np

# %%
a = [12,12,12,12]

# %%
a = np.array(a)

# %%
a = np.repeat(a.reshape(-1,1), repeats=5, axis = 1)

# %%
a = a.reshape(4,5,1)

# %%
b = np.random.normal(size= a.shape)
c = np.random.normal(size= a.shape)

# %%
x = np.concatenate((a,b,c), axis = -1)

# %%
x.shape
# Out:
# (4, 5, 3)

# %%
x_permute = np.swapaxes(np.swapaxes(x,0, 2),1,2)

# %%
x_permute.shape
# Out:
# (3, 4, 5)

# %%
x_fft  = np.fft.rfft2(x_permute)

# %%
x_fft[2,...]
# Out:
# array([[-3.82400856+0.j        ,  1.47736307-1.19484534j,
#         -0.26461138-0.27998393j],
#        [-2.64614907-1.97634603j, -0.35653931-2.53778946j,
#          0.06631778-3.30377809j],
#        [-1.62166349+0.j        , -4.02234469-3.48055113j,
#          7.88097299-7.30906238j],
#        [-2.64614907+1.97634603j,  6.28694119+3.72919101j,
#          0.06676807-4.99116959j]])
